# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([-6,6], [-10,10], c='r')
plt.xlabel('horizontal')
plt.ylabel('vertical')
plt.xlim(-10, 10)
plt.ylim(-15,  15)

plt.axhline(10,   ls=':',  lw=3.)
plt.axhline(-10,  ls=':',  lw=3.)

# %%
a,= plt.plot([1, 2, 3], [3, 6, 9])

# %%
line1, =plt.plot([1, 2, 3], [2, 4, 6])

# %%
line1

# %%
a

# %%
print(a)

# %%
print(line1)

# %%
plt.plot([1, 2, 3])

# %%
plt.plot([2,4, 6])

# %%
print(plt.gca().lines)
# Out:
# []
